# %%
from newspaper import Article

# %%
url_ft = "https://archive.is/gdAQ1"
url_wiki = "https://en.wikipedia.org/wiki/Testing_effect"
article = Article(url)

# %%
article.download()

# %%
article.html
# Out:
# ''

# %%
article.parse()
article.text
# Out:
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 article.parse()
#       2 article.text
#
# File ~/opt/anaconda3/envs/newspeak/lib/python3.11/site-packages/newspaper/article.py:191, in Article.parse(self)
#     190 def parse(self):
# --> 191     self.throw_if_not_downloaded_verbose()
#     193     self.doc = self.config.get_parser().fromstring(self.html)
#     194     self.clean_doc = copy.deepcopy(self.doc)
#
# File ~/opt/anaconda3/envs/newspeak/lib/python3.11/site-packages/newspaper/article.py:531, in Article.throw_if_not_downloaded_verbose(self)
#     529     raise ArticleException('You must `download()` an article first!')
#     530 elif self.download_state == ArticleDownloadState.FAILED_RESPONSE:
# --> 531     raise ArticleException('Article `download()` failed with %s on URL %s' %
#     532           (self.download_exception_msg, self.url))
#
# ...

# %%
import article_parser

title, content = article_parser.parse(url="http://www.chinadaily.com.cn/a/202009/22/WS5f6962b2a31024ad0ba7afcb.html", output="markdown")
print(content)
# Out:
# ![](http://img2.chinadaily.com.cn/images/202009/22/5f6962b2a31024adbd959228.jpeg)
# Serbia's Novak Djokovic kisses the trophy after winning the final against
# Argentina's Diego Schwartzman at Italian Open, Foro Italico, Rome, Italy, Sept
# 21, 2020. [Photo/Agencies]
#
# ROME - Novak Djokovic won a record 36th Masters crown as he beat Diego
# Schwartzman in the men's final of the ATP Italian Open on Monday.
#
# Djokovic, the world number one and the top seed at the tournament, won 7-5,
# 6-3 against Argentine Schwartzman to lift his 36th Masters title, one more
# than Rafael Nadal.
#
# The Serb said he did not play his best tennis this time in Rome, but could
# find it when needed.
#
# Simona Halep, top seed of the women's draw, won her first title in Rome after
# defending champion Karolina Pliskova of the Czech Republic retired while
# trailing 6-0, 2-1 in the final.

# %%
from trafilatura import fetch_url, extract

downloaded = fetch_url(url_ft)
# Out:
# ERROR:root:download error: https://archive.is/gdAQ1 HTTPSConnectionPool(host='archive.is', port=443): Max retries exceeded with url: /gdAQ1 (Caused by ResponseError('too many 429 error responses'))

# %%
downloaded = fetch_url(url_wiki)

# %%
print(extract(downloaded, include_links=True, include_formatting=True))
# Out:
# WARNING:trafilatura.xml:missing link attribute: [9] {}
# WARNING:trafilatura.xml:missing link attribute: [14] {}
# # Testing effect
# The
# **testing effect** (also known as **retrieval practice**, **active recall**, **practice testing**, or **test-enhanced learning**) [[1]](#cite_note-1) [[2]](#cite_note-:15-2) suggests [3] [long-term memory](/wiki/Long-term_memory)is increased when part of the [learning](/wiki/Learning)period is devoted to retrieving information from [memory](/wiki/Memory). It is different from more general [[4]](#cite_note-4) *, defined in the APA Dictionary of Psychology as "any change or improvement that results from practice or repetition of task items or activities."* [practice effect](/wiki/Practice_effect) [[5]](#cite_note-5)
# Cognitive psychologists are working with educators to look at how to take advantage of tests—not as an assessment tool, but as a
# ...

# %%
url_long = "https://writings.stephenwolfram.com/2023/02/what-is-chatgpt-doing-and-why-does-it-work/"
downloaded = fetch_url(url_long)
print(extract(downloaded, include_links=True, include_formatting=True, output_format=""))
# Out:
# *“Wolfram|Alpha as the Way to Bring Computational Knowledge Superpowers to ChatGPT”*» *A discussion about the history of neural nets*»
# ## It’s Just Adding One Word at a Time
# That
# [ChatGPT](https://chat.openai.com/) can automatically generate something that reads even superficially like human-written text is remarkable, and unexpected. But how does it do it? And why does it work? My purpose here is to give a rough outline of what’s going on inside ChatGPT—and then to explore why it is that it can do so well in producing what we might consider to be meaningful text. I should say at the outset that I’m going to focus on the big picture of what’s going on—and while I’ll mention some engineering details, I won’t get deeply into them. (And the essence of what I’ll say applies just as well to other current “large language models” [LLMs] as to ChatGPT.)
# ...

# %%
downloaded
# Out:
# '<!DOCTYPE html>\n<html lang="en" prefix="fb: http://www.facebook.com/2008/fbml, og: http://ogp.me/ns#">\n<head>\n\n<!-- begin framework head en -->\n\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta charset="utf-8">\n    <meta name="msapplication-config" content="/browserconfig.xml">\n    <title>What Is ChatGPT Doing … and Why Does It Work?&mdash;Stephen Wolfram Writings</title>\n    <meta name="description" content="Stephen Wolfram explores the broader picture of what\'s going on inside ChatGPT and why it produces meaningful text. Discusses models, training neural nets, embeddings, tokens, transformers, language syntax.">\n    <meta property="og:image" content="https://content.wolfram.com/uploads/sites/43/2023/02/hero3-chat-exposition.png">\n    <meta property="og:url" content="https://writings.stephenwolfram.com/2023/02/what-is-chatgpt-doing-and-why-does-it-work/">\n    <meta property="o
# ...

# %%
from trafilatura import bare_extraction

meta = bare_extraction(downloaded)

# %%
meta.keys()
# Out:
# dict_keys(['title', 'author', 'url', 'hostname', 'description', 'sitename', 'date', 'categories', 'tags', 'fingerprint', 'id', 'license', 'body', 'comments', 'commentsbody', 'raw_text', 'text', 'language', 'image', 'pagetype'])

# %%
print(extract(downloaded, output_format="xml"))
# Out:
# <doc sitename="What Is ChatGPT Doing … and Why Does It Work?—Stephen Wolfram Writings" title="What Is ChatGPT Doing … and Why Does It Work?" date="2023-02-14" source="https://writings.stephenwolfram.com/2023/02/what-is-chatgpt-doing-and-why-does-it-work/" hostname="stephenwolfram.com" excerpt="Stephen Wolfram explores the broader picture of what's going on inside ChatGPT and why it produces meaningful text. Discusses models, training neural nets, embeddings, tokens, transformers, language syntax." categories="" tags="" fingerprint="kJMP/RvFh1rG0qDcGDcbUEGTj4I=">
#   <main>
#     <p>“Wolfram|Alpha as the Way to Bring Computational Knowledge Superpowers to ChatGPT” »A discussion about the history of neural nets »</p>
#     <head rend="h2">It’s Just Adding One Word at a Time</head>
# ...
